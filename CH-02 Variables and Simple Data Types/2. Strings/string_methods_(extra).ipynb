# %%
print('string'.capitalize())
# Out:
# String

# %%
print('sTRING StrinG'.casefold()) # The casefold() method returns a string where all the characters are lower case.
# Out:
# string string

# %%
print('string strings'.center(6))
print('string strings'.center(50)) # The center() method will center align the string, using a specified character 
                                   # (space is default) as the fill character.
print('string strings'.center(50,'*'))
# Out:
# string strings
#                   string strings
# ******************string strings******************

# %%
print('string'.count('l'))
print('string strings'.count('g'))    # count particular string's occurences in strings
print('string strings'.count('str'))
print('string STRings'.count('str'))
print('string strings'.count('sti'))
print('string strings'.count(' '))
# Out:
# 0
# 2
# 2
# 1
# 0
# 1

# %%
print('string STrings'.encode())

print('I 🧡 🏸 and 🏏')
print('I 🧡 🏸 and 🏏'.encode(encoding='ascii', errors='replace'))             # encoding
print('I 🧡 🏸 and 🏏'.encode(encoding='ascii', errors='ignore'))
print('I 🧡 🏸 and 🏏'.encode(encoding='ascii', errors='xmlcharrefreplace'))
print('I 🧡 🏸 and 🏏'.encode(encoding='ascii', errors='namereplace'))
print('I 🧡 🏸 and 🏏'.encode(encoding='ascii', errors='backslashreplace'))
# print('I 🧡 🏸 and 🏏'.encode(encoding='ascii', errors='strict'))          # Default, raises an error on failure
print('I 🧡 🏸 and 🏏'.encode(encoding='UTF-8', errors='namereplace'))
# print('I 🧡 🏸 and 🏏'.encode(encoding='Base64', errors='namereplace')) # explain lookup error and use codecs.encode()
# Out:
# b'string STrings'
# I 🧡 🏸 and 🏏
# b'I ? ? and ?'
# b'I   and '
# b'I &#129505; &#127992; and &#127951;'
# b'I \\N{ORANGE HEART} \\N{BADMINTON RACQUET AND SHUTTLECOCK} and \\N{CRICKET BAT AND BALL}'
# b'I \\U0001f9e1 \\U0001f3f8 and \\U0001f3cf'
# b'I \xf0\x9f\xa7\xa1 \xf0\x9f\x8f\xb8 and \xf0\x9f\x8f\x8f'

# %% [markdown]
# <a href = 'https://www.w3schools.com/python/ref_string_encode.asp'> See more about .encode().</a><br>
# <a href = 'https://gdgupta11.medium.com/understanding-different-types-of-encoding-540b403bff10'>Read more about encoding.</a>

# %%
print("string STrings".endswith('d'))
print("string STrings".endswith('s'))
print("string STrings".endswith('gs'))
print("I love python".endswith('love', 2, 6))                       # start value, stop value --> optional args
# Out:
# False
# True
# True
# True

# %%
print("I\tLove\tIndia".expandtabs())           # default tabsize (optional argument) is 8
print("I\tLove\tIndia".expandtabs(8))             
print("I\tLove\tIndia".expandtabs(60))
# Out:
# I       Love    India
# I       Love    India
# I                                                           Love                                                        India

# %%
print("string striNG".find('s'))    # returns index of the first occurence of string to be found in any string
print("string strinNG".find('NN'))  # if not found returns -1
print("string strinNG".find('s', 6, 9))
msg = "I love programming in Python"
print(msg.find('Python', 0, len(msg))) 
# print("string strinNG".find(56))   # have one parameter, only accept str type data as argument
# Out:
# 0
# -1
# 7
# 22

# %%
name = 'nobody'
print("My name is {}".format(name.title())) # string formatting

firstname = 'tom'
lastname = 'cruise'
print("My name is {} {}".format(firstname.title(), lastname.title()))
print("My name is {0} {1}".format(firstname.title(), lastname.title()))
print("My name is {1} {0}".format(firstname.title(), lastname.title()))
#print("My name is {2} {1}".format(firstname.title(), lastname.title()))  # indexing must be done properly
# Out:
# My name is Nobody
# My name is Tom Cruise
# My name is Tom Cruise
# My name is Cruise Tom

# %%
# SYNTAX: "{}".format_map(dictionary))    # return dictionary's key's value to different placeholders

# Example1
print('EXAMPLE1'.center(20, '*'))

favorite_numbers = {'name': 'ishan', 'fav_num': 8}
print("{name}'s favorite number is {fav_num}.".format_map(favorite_numbers))


# Example2
print('EXAMPLE2'.center(20, '*'))

person = {
    'name': ['john', 'jason'],
    'age': [23, 21]
}
msg = "{name[0]} is {age[0]} years old."

print(msg.format_map(person))
# Out:
# ******EXAMPLE1******
# ishan's favorite number is 8.
# ******EXAMPLE2******
# john is 23 years old.

# %%
# if printed using f-strings (below codes)

person = {
    'name_': ['john', 'jason'],
    'age': [23, 21]
}

name1 = person['name_'][0]
age1 = person['age'][0]
msg1 = f'{name1} is {age1} years old.'

print(msg1)
# Out:
# john is 23 years old.

# %%
print("Hello India".index('l'))
# Out:
# 2

# %%
print("Hello India".isalnum())
print("Hello India, today 10-12-2020".isalnum())
print("My greetings4India".isalnum())
print("MyGreetings4India".isalnum())
# Out:
# False
# False
# False
# True

# %%
print("Hello India".isalpha())
print("HelloIshan".isalpha())
print("Hello4MyIndia".isalpha())
# Out:
# False
# True
# False

# %%
print("Hello India".isascii())
print('0010001'.isascii())
print(' '.isascii())
print("We 💛 ⚽ and ⚾".isascii())
print("@!#$%^&*".isascii())
# Out:
# True
# True
# True
# False
# True

# %%
print("Hello India".isdecimal())
print('102'.isdecimal())
print("💛".isdecimal())
# Out:
# False
# True
# False

# %%
print("Hello mr. python".isdigit())
print("12".isdigit())
print("0".isdigit())
print("@".isdigit())
# Out:
# False
# True
# True
# False

# %%
# A Python identifier is a name used to identify a variable, function, class, module or other object.
print("Hello mr. python".isidentifier())
print('True'.isidentifier())
print('print'.isidentifier())
# Out:
# False
# True
# True

# %%
print("Hello mr. python".islower())
print("hello mr. python".islower())
# Out:
# False
# True

# %%
print("Hello mr. python".isnumeric())
print("4556".isnumeric())
print('145/5'.isnumeric())
# Out:
# False
# True
# False

# %%
print("Hello mr. python".isprintable())
print("🧔🏻👨🏻‍💻".isprintable())                  # difference b/w isacii() and isprintable() ?
print("Hello \n world".isprintable())
#print("Hello \n world".isascii())
# Out:
# True
# False
# False
# True

# %%
print("Hello mr. python".isspace())
print("  ".isspace())
# Out:
# False
# True

# %%
print("Hello mr. python".istitle())
print("Ayush anand".istitle())
print("Ayush Anand".istitle())
# Out:
# False
# False
# True

# %%
print("Ayush anand".isupper())
print("AYUSH ANAND".isupper())
# Out:
# False
# True

# %%
# The join() method takes all items in an iterable and joins them into one string.
# A string must be specified as the separator.
print("Ayush anand".join("*"))
print("Ayush anand".join("**"))
print("Ayush anand".join("***"))

print("Ayush anand".join("♦♦♦♦"))
print("hello".join([' 1 ', ' 2 ', ' 3 ', ' 4 ', ' 5 ', ' 6 ']))
# Out:
# *
# *Ayush anand*
# *Ayush anand*Ayush anand*
# ♦Ayush anand♦Ayush anand♦Ayush anand♦
#  1 hello 2 hello 3 hello 4 hello 5 hello 6

# %%
'a'*3 # extra
# Out:
# 'aaa'

# %%
print('a'.ljust(5,'*'))
print("Ayush anand".ljust(20, '#'))    # 1st parameter: total length, 2nd parameter: fill character (or char to be filled)
#print("Ayush anand".ljust(20, '$#'))   # fill character must be exactly 1 character long
# Out:
# a****
# Ayush anand#########
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-230-cb6069558365> in <module>
#       1 print('a'.ljust(5,'*'))
#       2 print("Ayush anand".ljust(20, '#'))    # 1st parameter: total length, 2nd parameter: char to be filled
# ----> 3 print("Ayush anand".ljust(20, '$#'))
#
# TypeError: The fill character must be exactly one character long

# %%
print('aA'.lower())
print('AA'.lower())
# Out:
# aa
# aa

# %%
print('a'.lstrip())
print('             a')
print('             a'.lstrip())       # remove left whitespaces
# Out:
# a
#              a
# a

# %% [markdown]
# ![string.maketrans%28x,y,z%29.PNG](attachment:string.maketrans%28x,y,z%29.PNG)
#
# <pre>
# <a href='https://medium.com/analytics-vidhya/when-and-where-to-use-maketrans-and-translate-in-python-764670ff91fe'>Read more.</a>
# maketrans() function is used to construct the transition table i.e specify the list of characters that
# need to be replaced in the whole string or the characters that need to be deleted from the string.
# <span style='background-color:yellow'>maketrans() — is used to create mapping between the variables,
# translate() — is used to convert string based on the mappings provided to it.</span>
# </pre>

# %%
# The maketrans() method returns a mapping table that can be used with the translate() method to replace 
# specified characters.

print('a'.maketrans({1: 'a', '2':'b'}))   # explain
print("Hellooo sam".maketrans('asm', 'oje', 'oo' ))
# Out:
# {1: 'a', 50: 'b'}
# {97: 111, 115: 106, 109: 101, 111: None}

# %%
print("Hellooo sam".translate("Hellooo sam".maketrans('asm', 'oje', 'oo' )))
# Out:
# Hell joe

# %% [markdown]
# <a href='https://medium.com/better-programming/5-different-ways-to-remove-specific-characters-from-a-string-in-python-b0e081839ab9'>5 Different Ways to Remove Specific Characters From a String in Python</a>

# %%
help(str.maketrans)   # about maketrans() method using in built help function of Python
# Out:
# Help on built-in function maketrans:
#
# maketrans(...)
#     Return a translation table usable for str.translate().
#
#     If there is only one argument, it must be a dictionary mapping Unicode
#     ordinals (integers) or characters to Unicode ordinals, strings or None.
#     Character keys will be then converted to ordinals.
#     If there are two arguments, they must be strings of equal length, and
#     in the resulting dictionary, each character in x will be mapped to the
#     character at the same position in y. If there is a third argument, it
#     must be a string, whose characters will be mapped to None in the result.

# %%
print("Hello, indians it is a nice morning in delhi.".partition('indians'))
# Out:
# ('Hello, ', 'indians', ' it is a nice morning in delhi.')

# %%
msg_parts = "Hello, indians it is a nice morning in delhi.".partition('indians')
print(msg_parts)
print('indians' in msg_parts)
# Out:
# ('Hello, ', 'indians', ' it is a nice morning in delhi.')
# True

# %% [markdown]
# <pre>
# The partition() method searches for a specified string, and splits the string into a tuple containing three elements.
# The first element contains the part before the specified string.
# The second element contains the specified string.
# The third element contains the part after the string.
# <span style='background-color:yellow'>Note: This method search for the first occurrence of the specified string.</span>
# </pre>

# %%
print("Hello indians, it is a nice morning in delhi.".replace('delhi', 'faridabad', 1))
print("Hello indians, it is a nice morning in delhi.".replace('delhi', 'faridabad'.title(), 3))
print("Hello indians, it is a nice morning in delhi.".replace('delhi',1234 , 3))
# Out:
# Hello indians, it is a nice morning in faridabad.
# Hello indians, it is a nice morning in Faridabad.
# Hello indians, it is a nice morning in delhi.

# %% [markdown]
# The replace() method replaces a specified phrase with another specified phrase.
# Note: All occurrences of the specified phrase will be replaced, if nothing else is specified.
# string.replace(oldvalue, newvalue, count)
# ![str.replace%28oldValue,%20newValue,%20count%29.PNG](attachment:str.replace%28oldValue,%20newValue,%20count%29.PNG)

# %%
# str.rfind()

# %% [markdown]
# <pre>
# The rfind() method finds the last occurrence of the specified value.
# The rfind() method returns -1 if the value is not found.
# The rfind() method is almost the same as the rindex().
# </pre>
# ![string.rfind%28value,start,end%29.PNG](attachment:string.rfind%28value,start,end%29.PNG)

# %%
print("Hello indians, it is a nice morning in delhi.".rfind('indian',2,14))
print("Hello ind ind ind.".rfind('ind')) # searches for the last occurence
# Out:
# 6
# 14

# %%
print("Hello indians, it is a nice morning in delhi.".rindex('i'))
print("Hello indians, it is a nice morning in delhi.".rindex('morning'))
# Out:
# 43
# 28

# %%
# The rjust() method will right align the string, using a specified character (space is default) as the fill character.
# string.rjust(length, character)  # length is for overall string
    
print("Hello indians".rjust(20, '#'))
print("Hello indians".rjust(20))       # by default, character is space
print("Hello indians".rjust(20))
print("Hello indians".rjust(8))        # if length specified is less than string length
# Out:
# #######Hello indians
#        Hello indians
#        Hello indians
# Hello indians

# %%
# rpartition() takes exactly one argument
# It parses the string from the right side and when a delimiter is found, it partition the string into two parts and 
# give back the tuple to you as is the case for partition()

print("Hello heroic indians".rpartition('z'))       # if string to be searched is not present in the parent string 
print("It is good. It is bad.".rpartition('is'))
print("It is good. It is bad.".partition('is'))     # see the difference between partion() and rpartition() method
# Out:
# ('', '', 'Hello heroic indians')
# ('It is good. It ', 'is', ' bad.')
# ('It ', 'is', ' good. It is bad.')

# %% [markdown]
# Read: <a href= 'https://www.computerhope.com/jargon/d/delimite.htm'>What is delimeter?</a><br>

# %%
# SYNTAX: string.rsplit(separator, maxsplit)
# The rsplit() method splits a string into a list, starting from the right.
# If no "max" is specified, this method will return the same as the split() method.
# Note: When maxsplit is specified, the list will contain the specified number of elements plus one.

print("It is good. It is bad.".rsplit('is'))
print("It is good. It is bad.".rsplit('is',1)) # see all outputs distinctly
print("It is good. It is bad.".rsplit('is',2))
# maxsplit can be any size(not give error) but split only the number of times separator is repeated, see below line's output
print("It is good. It is bad.".rsplit('is',5))
print("It is good. It is bad.".rsplit('*',5))  # observe the last output
print("It is good. It is bad.".rsplit()) # Default separator is any whitespace
# Out:
# ['It ', ' good. It ', ' bad.']
# ['It is good. It ', ' bad.']
# ['It ', ' good. It ', ' bad.']
# ['It ', ' good. It ', ' bad.']
# ['It is good. It is bad.']
# ['It', 'is', 'good.', 'It', 'is', 'bad.']

# %% [markdown]
# Understand: <a href= 'https://mylyfmycode.wordpress.com/2018/08/15/split-v-s-rsplit-partition-v-s-rpartition/#:~:text=It%20should%20be%20intuitive%20to,the%20case%20for%20partition().'>split() v/s rsplit() & partition() v/s rpartition()</a>

# %%
# SYNTAX: string.rstrip(characters)
# The rstrip() method removes any trailing characters (characters at the end a string), 
# space is the default trailing character to remove.

print("It is good. It is bad.exexexexexexexex".rstrip('ex'))
print("It is good. It is bad.   ".rstrip())
# Out:
# It is good. It is bad.
# It is good. It is bad.

# %% [markdown]
# Read more: <a href= 'https://www.journaldev.com/23625/python-trim-string-rstrip-lstrip-strip#:~:text=strip()%3A%20returns%20a%20new,right%E2%80%9D%20side%20of%20the%20string.'>Python Trim String – rstrip(), lstrip(), strip()</a>

# %% [markdown]
# ![string.split%28sparator,maxsplit%29.PNG](attachment:string.split%28sparator,maxsplit%29.PNG)

# %%
print("It is good. It is bad.".split('.'))
print("It is good. It is bad.".split('is',1))
print("It is good. It is bad.".split('is', 2))
print("It is good. It is bad.".split())
# Out:
# ['It is good', ' It is bad', '']
# ['It ', ' good. It is bad.']
# ['It ', ' good. It ', ' bad.']
# ['It', 'is', 'good.', 'It', 'is', 'bad.']

# %% [markdown]
# ![str.splitlines%28keeplinebreaks%29.PNG](attachment:str.splitlines%28keeplinebreaks%29.PNG)

# %%
# string.splitlines(keeplinebreaks)
# The splitlines() method splits a string into a list. The splitting is done at line breaks.

print("It is good.\nIt is bad.")
print("It is good.\nIt is bad.".splitlines())
print("It is good.\nIt is bad.".splitlines(True))
# Out:
# It is good.
# It is bad.
# ['It is good.', 'It is bad.']
# ['It is good.\n', 'It is bad.']

# %% [markdown]
# ![str.startswith%28value,start,end%29.PNG](attachment:str.startswith%28value,start,end%29.PNG)

# %%
# SYNTAX: string.startswith(value, start, end)

print("It is good. It is bad.".startswith("it"))
print("It is good. It is bad.".startswith("It"))
print("It is good. It is bad.".startswith('It', 2))
print("It is good. It is bad.".startswith('It', 0, 5))
# Out:
# False
# True
# False
# True

# %%
print("It is good. It is bad.".strip())
#print("              It is good. It is bad.             ")
print("              It is good. It is bad.             ".strip())
print("xxxxxxxxxIt is good. It is bad.xxxxxxxxxxxxxxxxxxxx".strip('x'))
# Out:
# It is good. It is bad.
# It is good. It is bad.
# It is good. It is bad.

# %%
print("It is good. It is bad.".swapcase())
print("Iiiii".swapcase())
# Out:
# iT IS GOOD. iT IS BAD.
# iIIII

# %%
print("It is good. It is bad.".title())
# Out:
# It Is Good. It Is Bad.

# %% [markdown]
# ![string.translate%28table%29.PNG](attachment:string.translate%28table%29.PNG)
# <pre>
# The translate() method returns a string where some specified characters are replaced with the character
# described in a dictionary, or in a mapping table.
#
# Use the maketrans() method to create a mapping table.
# If a character is not specified in the dictionary/table, the character will not be replaced.
# If we use a dictionary, we must use ascii codes instead of characters.
# </pre>

# %%
print("It is good. It is bad.".translate({98:66, 97:65, 100:68})) # 97 --> a, 65 --> A
 
mydict = {83:  80};
txt = "Hello Sam!";
print(txt.translate(mydict));
# Out:
# It is gooD. It is BAD.
# Hello Pam!

# %%
print("It is good. It is bad.".upper())
# Out:
# IT IS GOOD. IT IS BAD.

# %%
# The zfill() method adds zeros (0) at the beginning of the string, until it reaches the specified length.
# If the value of the len parameter is less than the length of the string, no filling is done.
# SYNTAX: string.zfill(len)
# len: represent final length of string

print("1".zfill(4))
print("2".zfill(6))
print("It is good. It is bad.".zfill(30))
# Out:
# 0001
# 000002
# 00000000It is good. It is bad.

# %% [markdown]
# <hr style=bold>
