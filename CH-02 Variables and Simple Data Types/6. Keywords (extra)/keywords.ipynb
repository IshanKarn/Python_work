# %% [markdown]
# ## Keywords
#
# <span style='background-color: yellow'>Python has a set of <a href='https://www.javatpoint.com/python-keywords'>keywords</a> that are reserved words that cannot be used as variable names, function names, or any other identifiers:</span><br>
# These are special reserved words that convey a special meaning to the compiler/interpreter. Each keyword has a special meaning and a specific operation. These keywords can't be used as a variable.<br>
# Following are python keywords and their short descriptions:

# %% [markdown]
# ![keywords-part1.PNG](attachment:keywords-part1.PNG)
# ![kewords-part2.PNG](attachment:kewords-part2.PNG)

# %% [markdown]
# #### Example Programs (for each keywords)

# %%
# It will be added one by one as we go through the related topics
